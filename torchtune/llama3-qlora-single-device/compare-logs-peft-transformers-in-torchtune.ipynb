# %% [markdown]
# # Comparison of logs from torchtune and PEFT

# %% [markdown]
# Use torchtune QLoRA (torchao) training recipe but use PEFT for the LoRA implementation and transformers + bnb for the base model instead of torchtune.

# %% [markdown]
# ## imports

# %%
import re

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## load data

# %% [markdown]
# ### load torchtune logs

# %%
with open("log_torchtune.txt", "r") as f:
    logs_tt = f.readlines()

# %%
pattern = re.compile(
    r"Step (\d+) \| loss:(\d+\.\d+) lr:(\d+\.\d+(?:e-\d+)?) tokens_per_second_per_gpu:(\d+\.\d+) "
    r"peak_memory_active:(\d+\.\d+) peak_memory_alloc:(\d+\.\d+) peak_memory_reserved:(\d+\.\d+)")
rows = []
for log in logs_tt:
    row = pattern.match(log.strip()).groups()
    step, loss, lr, dur, peak_memory_active, peak_memory_alloc, peak_memory_reserved = row
    rows.append((int(step), float(loss), float(lr), float(dur), float(peak_memory_active), float(peak_memory_alloc), float(peak_memory_reserved)))

# %%
df_tt = pd.DataFrame(
    rows,
    columns=["step", "loss", "lr", "tokens_per_second", "peak_memory_active", "peak_memory_alloc", "peak_memory_reserved"],
)

# %%
df_tt.shape
# Out:
# (652, 7)

# %% [markdown]
# ### load peft logs

# %%
with open("log_peft_transformers_in_torchtune.txt", "r") as f:
    logs_peft = f.readlines()

# %%
rows = []
for log in logs_peft:
    row = pattern.match(log.strip()).groups()
    step, loss, lr, dur, peak_memory_active, peak_memory_alloc, peak_memory_reserved = row
    rows.append((int(step), float(loss), float(lr), float(dur), float(peak_memory_active), float(peak_memory_alloc), float(peak_memory_reserved)))

# %%
df_peft = pd.DataFrame(
    rows,
    columns=["step", "loss", "lr", "tokens_per_second", "peak_memory_active", "peak_memory_alloc", "peak_memory_reserved"]
)

# %%
df_peft.shape
# Out:
# (214, 7)

# %% [markdown]
# ### join

# %%
df = df_tt.merge(df_peft, on="step", suffixes=("_tt", "_peft"), how="outer")

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (214, 13)

# %% [markdown]
# ## comparison

# %% [markdown]
# ### loss

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
kw = {"ylim": [0, 3], "ylabel": "loss", "xlabel": "step"}
df[["loss_tt", "loss_peft"]].head(100).plot(ax=axes[0], title="loss first 100 steps", **kw)
df[["loss_tt", "loss_peft"]].rolling(20).mean().head(100).plot(ax=axes[1], title="loss first 100 steps, rolling mean (20)", **kw)
# Out:
# <Axes: title={'center': 'loss first 100 steps, rolling mean (20)'}, xlabel='step', ylabel='loss'>

# %% [markdown]
# ### tokens per second

# %%
fig, ax = plt.subplots(figsize=(16, 6))
kw = {"ylabel": "tokens per second", "xlabel": "step", "ylim": [0, 4000]}
df[["tokens_per_second_tt", "tokens_per_second_peft"]].plot(ax=ax, title="tokens per second", **kw)
# Out:
# <Axes: title={'center': 'tokens per second'}, xlabel='step', ylabel='tokens per second'>

# %% [markdown]
# ### tokens per second (rolling mean)

# %%
fig, ax = plt.subplots(figsize=(16, 6))
kw = {"ylabel": "tokens per second", "xlabel": "step", "ylim": [0, 4000]}
df[["tokens_per_second_tt", "tokens_per_second_peft"]].rolling(50).mean().plot(ax=ax, title="tokens per second, rolling mean (50)", **kw)
# Out:
# <Axes: title={'center': 'tokens per second, rolling mean (50)'}, xlabel='step', ylabel='tokens per second'>

# %% [markdown]
# ### memory

# %%
fig, ax = plt.subplots(figsize=(16, 6))
kw = {"ylabel": "memory (GB)", "xlabel": "step", "ylim": [0, 20]}
df[["peak_memory_alloc_tt", "peak_memory_reserved_tt", "peak_memory_alloc_peft", "peak_memory_reserved_peft"]].plot(ax=ax, title="memory", **kw)
# Out:
# <Axes: title={'center': 'memory'}, xlabel='step', ylabel='memory (GB)'>

# %% [markdown]
# ### memory (rolling mean)

# %%
fig, ax = plt.subplots(figsize=(16, 6))
kw = {"ylabel": "memory (GB)", "xlabel": "step", "ylim": [0, 15]}
df[["peak_memory_alloc_tt", "peak_memory_reserved_tt", "peak_memory_alloc_peft", "peak_memory_reserved_peft"]].rolling(20).mean().plot(ax=ax, title="memory, rolling mean (20)", **kw)
# Out:
# <Axes: title={'center': 'memory, rolling mean (20)'}, xlabel='step', ylabel='memory (GB)'>

# %%
df[sorted(df)].describe().T[["mean", "50%"]]
# Out:
#                                   mean          50%
# loss_peft                     1.176451     1.060209
# loss_tt                       1.063748     0.981787
# lr_peft                       0.000231     0.000300
# lr_tt                         0.000231     0.000300
# peak_memory_active_peft      12.439276    12.502030
# peak_memory_active_tt         7.514234     7.510834
# peak_memory_alloc_peft       12.439276    12.502030
# peak_memory_alloc_tt          7.514234     7.510834
# peak_memory_reserved_peft    16.268137    16.391340
# peak_memory_reserved_tt      12.814941    12.920553
# step                        107.500000   107.500000
# tokens_per_second_peft     2741.520846  2773.842565
# tokens_per_second_tt        473.420853   474.028529
